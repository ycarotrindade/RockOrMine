# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import GridSearchCV, StratifiedKFold,train_test_split
import warnings
import pickle

# %%
DATABASE_PATH = ""
df = pd.read_csv(DATABASE_PATH)

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0200  207 non-null    float64
#  1   0.0371  207 non-null    float64
#  2   0.0428  207 non-null    float64
#  3   0.0207  207 non-null    float64
#  4   0.0954  207 non-null    float64
#  5   0.0986  207 non-null    float64
#  6   0.1539  207 non-null    float64
#  7   0.1601  207 non-null    float64
#  8   0.3109  207 non-null    float64
#  9   0.2111  207 non-null    float64
#  10  0.1609  207 non-null    float64
#  11  0.1582  207 non-null    float64
#  12  0.2238  207 non-null    float64
#  13  0.0645  207 non-null    float64
#  14  0.0660  207 non-null    float64
#  15  0.2273  207 non-null    float64
#  16  0.3100  207 non-null    float64
#  17  0.2999  207 non-null    float64
#  18  0.5078  207 non-null    float64
#  19  0.4797  207 non-null    float64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
label_series = df['R'].value_counts()
fig, ax = plt.subplots()
ax.bar(label_series.index,label_series.values)
ax.set_title("Label Count")
ax.set_xlabel("Categories")
ax.set_ylabel("Values")
for p in ax.patches:
  _x = p.get_x() + p.get_width() - 0.5
  _y = p.get_y() + p.get_height()
  value = int(p.get_height())
  ax.text(_x,_y,value,ha="left")
plt.show()

# %% [markdown]
# This line indicates there is a slight imbalance in the target column. To correct this we will use the **StratifiedKFold** function.

# %% [markdown]
# # Transforming data

# %%
y = df.iloc[:,60:]
encoder = LabelEncoder()
y_transformed = encoder.fit_transform(y)

# %% [markdown]
# The **LabelEncoder** object will transform the categorical values into numerical values

# %%
X = df.iloc[:,:60]
scaler = StandardScaler()
X_transformed = X

# %% [markdown]
# The **StandardScaller** object will Standardize the features

# %% [markdown]
# # Evaluating best params

# %%
model = LogisticRegression()
param_grid = {
    'penalty':['none','l2','l1','elasticnet'],
    'solver':['newton-cg','lbfgs','liblinear','sag','saga'],
    'C':np.logspace(-3,3,7)
}
cv = StratifiedKFold(n_splits=10,shuffle=True,random_state=5)
gridsearch = GridSearchCV(model,param_grid=param_grid,cv=cv)

# %%
warnings.filterwarnings('ignore')
gridsearch.fit(X_transformed,y_transformed)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=5, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03]),
#                          'penalty': ['none', 'l2', 'l1', 'elasticnet'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']})

# %%
print(gridsearch.best_score_)
print(gridsearch.best_params_)
# Out:
# 0.806904761904762
# {'C': 1.0, 'penalty': 'l1', 'solver': 'saga'}

# %% [markdown]
# # Making the model

# %%
X_train,X_test,y_train,y_test = train_test_split(X_transformed,y_transformed,shuffle=True,random_state=5,test_size=0.2)

# %%
params= gridsearch.best_params_.copy()

# %%
model_best_features = LogisticRegression(C=params['C'],penalty=params['penalty'],solver=params['solver'])
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
preds = model.predict(X_test)
print(accuracy_score(y_test,preds))
# Out:
# 0.8095238095238095

# %%
response = input('Do you want to save the model?(Y/n): ').lower()
if response == 'y':
  with open('model.pkl','wb') as f:
    pickle.dump(model_best_features,f)
# Out:
# Do you want to save the model?(Y/n): y
